# %%
import numpy as np # linear algebra
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv("train.csv")

# %%
df.head()
# Out:
#   customer_id  customer_age     job_type  marital  education default  balance  \
# 0    id_32289          34.0  blue-collar  married  secondary      no    934.0
# 1    id_40992          41.0  blue-collar  married    primary      no   1352.0
# 2    id_41178          57.0  blue-collar  married    primary      no    495.0
# 3    id_35102          37.0   management  married   tertiary      no    650.0
# 4    id_34750          29.0   technician  married  secondary      no    265.0
#
#   housing_loan personal_loan communication_type  day_of_month month  \
# 0           no           yes           cellular            18   nov
# 1          yes            no           cellular            13   may
# 2           no            no           cellular            18   aug
# 3          yes           NaN            unknown            26   may
# 4          yes            no           cellular            19   aug
#
#    last_contact_duration  num_contacts_in_campaign  \
# 0                    704                       2.0
# 1                    893                       2.0
# 2                    796                       4.0
# 3                    880                       1.0
# 4                    795                       2.0
#
#    num_contacts_prev_campaign prev_campaign_outcome  term_deposit_subscribed
# 0                           1                 other                        0
# 1                           0               unknown                        0
# 2                           0               unknown                        1
# 3                           0               unknown                        0
# 4                           0               unknown                        0

# %%
df.shape
# Out:
# (23880, 17)

# %%
df.isnull().sum()
# Out:
# customer_id                     0
# customer_age                  477
# job_type                        0
# marital                       107
# education                       0
# default                         0
# balance                       277
# housing_loan                    0
# personal_loan                 113
# communication_type              0
# day_of_month                    0
# month                           0
# last_contact_duration           0
# num_contacts_in_campaign       96
# num_contacts_prev_campaign      0
# prev_campaign_outcome           0
# term_deposit_subscribed         0
# dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 23880 entries, 0 to 23879
# Data columns (total 17 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   customer_id                 23880 non-null  object
#  1   customer_age                23403 non-null  float64
#  2   job_type                    23880 non-null  object
#  3   marital                     23773 non-null  object
#  4   education                   23880 non-null  object
#  5   default                     23880 non-null  object
#  6   balance                     23603 non-null  float64
#  7   housing_loan                23880 non-null  object
#  8   personal_loan               23767 non-null  object
#  9   communication_type          23880 non-null  object
#  10  day_of_month                23880 non-null  int64
#  11  month                       23880 non-null  object
#  12  last_contact_duration       23880 non-null  int64
#  13  num_contacts_in_campaign    23784 non-null  float64
#  14  num_contacts_prev_campaign  23880 non-null  int64
#  15  prev_campaign_outcome       23880 non-null  object
#  16  term_deposit_subscribed     23880 non-null  int64
# dtypes: float64(3), int64(4), object(10)
# memory usage: 2.2+ MB

# %%
for column in df.columns:
    print(column,df[column].nunique())
# Out:
# customer_id 23880
# customer_age 75
# job_type 12
# marital 3
# education 4
# default 2
# balance 5811
# housing_loan 2
# personal_loan 2
# communication_type 3
# day_of_month 31
# month 12
# last_contact_duration 312
# num_contacts_in_campaign 44
# num_contacts_prev_campaign 38
# prev_campaign_outcome 4
# term_deposit_subscribed 2

# %%
df.describe()
# Out:
#        customer_age       balance  day_of_month  last_contact_duration  \
# count  23403.000000  23603.000000  23880.000000           23880.000000
# mean      40.394821   1363.966106     15.796315             854.879648
# std       10.753045   3019.583085      8.321136              74.537616
# min       18.000000  -8020.000000      1.000000             661.000000
# 25%       32.000000     71.000000      8.000000             809.000000
# 50%       38.000000    443.000000     16.000000             871.000000
# 75%       48.000000   1410.500000     21.000000             897.000000
# max       93.000000  98419.000000     31.000000            1019.000000
#
#        num_contacts_in_campaign  num_contacts_prev_campaign  \
# count              23784.000000                23880.000000
# mean                   2.775353                    0.583836
# std                    3.148117                    2.624465
# min                    1.000000                    0.000000
# 25%                    1.000000                    0.000000
# 50%                    2.000000                    0.000000
# 75%                    3.000000                    0.000000
# max                   63.000000                  275.000000
#
#        term_deposit_subscribed
# count             23880.000000
# mean                  0.106198
# std                   0.308097
# min                   0.000000
# 25%                   0.000000
# 50%                   0.000000
# 75%                   0.000000
# max                   1.000000

# %%
df.term_deposit_subscribed.value_counts()
# Out:
# 0    21344
# 1     2536
# Name: term_deposit_subscribed, dtype: int64

# %%
sns.countplot(x='term_deposit_subscribed',data=df)
# Out:
# <AxesSubplot:xlabel='term_deposit_subscribed', ylabel='count'>

# %%
for col in df.select_dtypes(include='object').columns:
  print(col)
  print(df[col].unique())
# Out:
# customer_id
# ['id_32289' 'id_40992' 'id_41178' ... 'id_44679' 'id_4841' 'id_1723']
# job_type
# ['blue-collar' 'management' 'technician' 'services' 'retired'
#  'entrepreneur' 'admin.' 'student' 'housemaid' 'self-employed' 'unknown'
#  'unemployed']
# marital
# ['married' 'single' 'divorced' nan]
# education
# ['secondary' 'primary' 'tertiary' 'unknown']
# default
# ['no' 'yes']
# housing_loan
# ['no' 'yes']
# personal_loan
# ['yes' 'no' nan]
# communication_type
# ['cellular' 'unknown' 'telephone']
# month
# ['nov' 'may' 'aug' 'apr' 'feb' 'jun' 'jul' 'jan' 'oct' 'sep' 'mar' 'dec']
# prev_campaign_outcome
# ['other' 'unknown' 'failure' 'success']

# %%
sns.countplot(y='job_type',data=df)
# Out:
# <AxesSubplot:xlabel='count', ylabel='job_type'>

# %%
sns.countplot(y='marital',data=df)
# Out:
# <AxesSubplot:xlabel='count', ylabel='marital'>

# %%
sns.countplot(y='education',data=df)
# Out:
# <AxesSubplot:xlabel='count', ylabel='education'>

# %%
sns.countplot(y='default',data=df) #unimportant
# Out:
# <AxesSubplot:xlabel='count', ylabel='default'>

# %%
sns.countplot(y='housing_loan',data=df) #balance in the feature
# Out:
# <AxesSubplot:xlabel='count', ylabel='housing_loan'>

# %%
sns.countplot(y='personal_loan',data=df) #with no loans don't opt for term deposits
# Out:
# <AxesSubplot:xlabel='count', ylabel='personal_loan'>

# %%
sns.countplot(y='communication_type',data=df)
# Out:
# <AxesSubplot:xlabel='count', ylabel='communication_type'>

# %%
sns.countplot(y='month',data=df)
# Out:
# <AxesSubplot:xlabel='count', ylabel='month'>

# %%
sns.countplot(y='prev_campaign_outcome',data=df)
# Out:
# <AxesSubplot:xlabel='count', ylabel='prev_campaign_outcome'>

# %%
df.customer_age=df.customer_age.fillna(34)
df
# Out:
#       customer_id  customer_age     job_type  marital  education default  \
# 0        id_32289          34.0  blue-collar  married  secondary      no
# 1        id_40992          41.0  blue-collar  married    primary      no
# 2        id_41178          57.0  blue-collar  married    primary      no
# 3        id_35102          37.0   management  married   tertiary      no
# 4        id_34750          29.0   technician  married  secondary      no
# ...           ...           ...          ...      ...        ...     ...
# 23875    id_27290          58.0       admin.  married  secondary      no
# 23876    id_20428          51.0   management  married   tertiary      no
# 23877    id_44679          41.0   unemployed  married    primary      no
# 23878     id_4841          48.0     services  married  secondary      no
# 23879     id_1723          38.0   technician   single   tertiary      no
#
#        balance housing_loan personal_loan communication_type  day_of_month  \
# 0        934.0           no           yes           cellular            18
# 1       1352.0          yes            no           cellular            13
# 2        495.0           no            no           cellular            18
# 3        650.0          yes           NaN            unknown            26
# 4        265.0          yes            no           cellular            19
# ...        ...          ...           ...                ...           ...
# 23875    567.0          yes            no           cellular             2
# 23876   1072.0           no            no            unknown            20
# 23877    242.0          yes            no            unknown            23
# 23878   2699.0           no            no           cellular            11
# 23879   1045.0           no            no           cellular            18
#
#       month  last_contact_duration  num_contacts_in_campaign  \
# 0       nov                    704                       2.0
# 1       may                    893                       2.0
# 2       aug                    796                       4.0
# 3       may                    880                       1.0
# 4       aug                    795                       2.0
# ...     ...                    ...                       ...
# 23875   feb                    993                       2.0
# 23876   jun                    855                       7.0
# 23877   may                    883                       2.0
# 23878   aug                    803                       6.0
# 23879   aug                    796                      10.0
#
#        num_contacts_prev_campaign prev_campaign_outcome  \
# 0                               1                 other
# 1                               0               unknown
# 2                               0               unknown
# 3                               0               unknown
# 4                               0               unknown
# ...                           ...                   ...
# 23875                           3                 other
# 23876                           0               unknown
# 23877                           0               unknown
# 23878                           0               unknown
# 23879                           0               unknown
#
#        term_deposit_subscribed
# 0                            0
# 1                            0
# 2                            1
# 3                            0
# 4                            0
# ...                        ...
# 23875                        0
# 23876                        0
# 23877                        0
# 23878                        0
# 23879                        0
#
# [23880 rows x 17 columns]

# %%
df.isnull().sum()
# Out:
# customer_id                     0
# customer_age                    0
# job_type                        0
# marital                       107
# education                       0
# default                         0
# balance                       277
# housing_loan                    0
# personal_loan                 113
# communication_type              0
# day_of_month                    0
# month                           0
# last_contact_duration           0
# num_contacts_in_campaign       96
# num_contacts_prev_campaign      0
# prev_campaign_outcome           0
# term_deposit_subscribed         0
# dtype: int64

# %%
df = df.replace('unknown', np.NaN)

# %%
df.isnull().sum()
# Out:
# customer_id                       0
# customer_age                      0
# job_type                        154
# marital                         107
# education                       986
# default                           0
# balance                         277
# housing_loan                      0
# personal_loan                   113
# communication_type             6892
# day_of_month                      0
# month                             0
# last_contact_duration             0
# num_contacts_in_campaign         96
# num_contacts_prev_campaign        0
# prev_campaign_outcome         19513
# term_deposit_subscribed           0
# dtype: int64

# %%
df = df[df.job_type.notna()]
df.isnull().sum()
# Out:
# customer_id                       0
# customer_age                      0
# job_type                          0
# marital                         107
# education                       915
# default                           0
# balance                         277
# housing_loan                      0
# personal_loan                   113
# communication_type             6831
# day_of_month                      0
# month                             0
# last_contact_duration             0
# num_contacts_in_campaign         95
# num_contacts_prev_campaign        0
# prev_campaign_outcome         19377
# term_deposit_subscribed           0
# dtype: int64

# %%
df = df[df.marital.notna()]
df.isnull().sum()
# Out:
# customer_id                       0
# customer_age                      0
# job_type                          0
# marital                           0
# education                       913
# default                           0
# balance                         273
# housing_loan                      0
# personal_loan                   113
# communication_type             6795
# day_of_month                      0
# month                             0
# last_contact_duration             0
# num_contacts_in_campaign         95
# num_contacts_prev_campaign        0
# prev_campaign_outcome         19294
# term_deposit_subscribed           0
# dtype: int64

# %%
def randomCatFill(df, colName):
    perm = np.random.permutation(df[colName])
    
    perm = perm[~pd.isnull(perm)]
    
    end = len(perm)
    df[colName] = df[colName].apply(lambda x: perm[np.random.randint(end)] if pd.isnull(x) else x)

# %%
randomCatFill(df, 'education')
randomCatFill(df, 'personal_loan')
randomCatFill(df, 'communication_type')

# %%
df.isnull().sum()
# Out:
# customer_id                       0
# customer_age                      0
# job_type                          0
# marital                           0
# education                         0
# default                           0
# balance                         273
# housing_loan                      0
# personal_loan                     0
# communication_type                0
# day_of_month                      0
# month                             0
# last_contact_duration             0
# num_contacts_in_campaign         95
# num_contacts_prev_campaign        0
# prev_campaign_outcome         19294
# term_deposit_subscribed           0
# dtype: int64

# %%
df.prev_campaign_outcome = df.prev_campaign_outcome.fillna("nonexistent")

# %%
df.isnull().sum()
# Out:
# customer_id                     0
# customer_age                    0
# job_type                        0
# marital                         0
# education                       0
# default                         0
# balance                       273
# housing_loan                    0
# personal_loan                   0
# communication_type              0
# day_of_month                    0
# month                           0
# last_contact_duration           0
# num_contacts_in_campaign       95
# num_contacts_prev_campaign      0
# prev_campaign_outcome           0
# term_deposit_subscribed         0
# dtype: int64

# %%
df = df[df.num_contacts_in_campaign.notna()]
df.isnull().sum()
# Out:
# customer_id                     0
# customer_age                    0
# job_type                        0
# marital                         0
# education                       0
# default                         0
# balance                       273
# housing_loan                    0
# personal_loan                   0
# communication_type              0
# day_of_month                    0
# month                           0
# last_contact_duration           0
# num_contacts_in_campaign        0
# num_contacts_prev_campaign      0
# prev_campaign_outcome           0
# term_deposit_subscribed         0
# dtype: int64

# %%
df.balance.mode()
# Out:
# 0    3.0
# dtype: float64

# %%
current_balance = df.pivot_table(values='balance', columns='job_type', aggfunc=(lambda x: x.mean()[0]))

# %%
current_balance
# Out:
# job_type       admin.  blue-collar  entrepreneur  housemaid   management  \
# balance   1125.321563  1102.675761   1512.725955    1442.75  1794.717285
#
# job_type     retired  self-employed   services      student   technician  \
# balance   2000.95986     1677.40311  965.30371  1326.635628  1227.701282
#
# job_type   unemployed
# balance   1419.781297

# %%
miss_values = df['balance'].isnull()

# %%
miss_values
# Out:
# 0        False
# 1        False
# 2        False
# 3        False
# 4        False
#          ...
# 23875    False
# 23876    False
# 23877    False
# 23878    False
# 23879    False
# Name: balance, Length: 23524, dtype: bool

# %%
df.loc[miss_values, 'balance'] = df.loc[miss_values,'job_type'].apply(lambda x: current_balance[x])

# %%
df.isnull().sum()
# Out:
# customer_id                   0
# customer_age                  0
# job_type                      0
# marital                       0
# education                     0
# default                       0
# balance                       0
# housing_loan                  0
# personal_loan                 0
# communication_type            0
# day_of_month                  0
# month                         0
# last_contact_duration         0
# num_contacts_in_campaign      0
# num_contacts_prev_campaign    0
# prev_campaign_outcome         0
# term_deposit_subscribed       0
# dtype: int64

# %%
df.balance
# Out:
# 0         934.0
# 1        1352.0
# 2         495.0
# 3         650.0
# 4         265.0
#           ...
# 23875     567.0
# 23876    1072.0
# 23877     242.0
# 23878    2699.0
# 23879    1045.0
# Name: balance, Length: 23524, dtype: float64

# %% [markdown]
# ### Corelation Matrix

# %%
# get the correlation matrix
corr = df.corr()

# create a mask for the upper triangle
mask = np.zeros_like(corr, dtype = np.bool)
mask[np.triu_indices_from(mask)] = True

# plot the correlation heatmap
sns.heatmap(corr, vmin=0, vmax=1, square=True,
           linewidths=.5, mask=mask, fmt='.2f')
# Out:
# <AxesSubplot:>

# %%
df.head()
# Out:
#   customer_id  customer_age     job_type  marital  education default  balance  \
# 0    id_32289          34.0  blue-collar  married  secondary      no    934.0
# 1    id_40992          41.0  blue-collar  married    primary      no   1352.0
# 2    id_41178          57.0  blue-collar  married    primary      no    495.0
# 3    id_35102          37.0   management  married   tertiary      no    650.0
# 4    id_34750          29.0   technician  married  secondary      no    265.0
#
#   housing_loan personal_loan communication_type  day_of_month month  \
# 0           no           yes           cellular            18   nov
# 1          yes            no           cellular            13   may
# 2           no            no           cellular            18   aug
# 3          yes            no           cellular            26   may
# 4          yes            no           cellular            19   aug
#
#    last_contact_duration  num_contacts_in_campaign  \
# 0                    704                       2.0
# 1                    893                       2.0
# 2                    796                       4.0
# 3                    880                       1.0
# 4                    795                       2.0
#
#    num_contacts_prev_campaign prev_campaign_outcome  term_deposit_subscribed
# 0                           1                 other                        0
# 1                           0           nonexistent                        0
# 2                           0           nonexistent                        1
# 3                           0           nonexistent                        0
# 4                           0           nonexistent                        0

# %%
from sklearn.preprocessing import LabelEncoder
le=LabelEncoder()

df['n_job']=le.fit_transform(df['job_type'])
df['n_marital']=le.fit_transform(df['marital'])
df['n_education']=le.fit_transform(df['education'])
df['n_loan']=le.fit_transform(df['personal_loan'])
df['n_contact']=le.fit_transform(df['communication_type'])
df['n_month']=le.fit_transform(df['month'])
df['n_poutcome']=le.fit_transform(df['prev_campaign_outcome'])

# %%
df
# Out:
#       customer_id  customer_age     job_type  marital  education default  \
# 0        id_32289          34.0  blue-collar  married  secondary      no
# 1        id_40992          41.0  blue-collar  married    primary      no
# 2        id_41178          57.0  blue-collar  married    primary      no
# 3        id_35102          37.0   management  married   tertiary      no
# 4        id_34750          29.0   technician  married  secondary      no
# ...           ...           ...          ...      ...        ...     ...
# 23875    id_27290          58.0       admin.  married  secondary      no
# 23876    id_20428          51.0   management  married   tertiary      no
# 23877    id_44679          41.0   unemployed  married    primary      no
# 23878     id_4841          48.0     services  married  secondary      no
# 23879     id_1723          38.0   technician   single   tertiary      no
#
#        balance housing_loan personal_loan communication_type  ...  \
# 0        934.0           no           yes           cellular  ...
# 1       1352.0          yes            no           cellular  ...
# 2        495.0           no            no           cellular  ...
# 3        650.0          yes            no           cellular  ...
# 4        265.0          yes            no           cellular  ...
# ...        ...          ...           ...                ...  ...
# 23875    567.0          yes            no           cellular  ...
# 23876   1072.0           no            no           cellular  ...
# 23877    242.0          yes            no           cellular  ...
# 23878   2699.0           no            no           cellular  ...
# 23879   1045.0           no            no           cellular  ...
#
#        num_contacts_prev_campaign prev_campaign_outcome  \
# 0                               1                 other
# 1                               0           nonexistent
# 2                               0           nonexistent
# 3                               0           nonexistent
# 4                               0           nonexistent
# ...                           ...                   ...
# 23875                           3                 other
# 23876                           0           nonexistent
# 23877                           0           nonexistent
# 23878                           0           nonexistent
# 23879                           0           nonexistent
#
#        term_deposit_subscribed  n_job  n_marital n_education  n_loan  \
# 0                            0      1          1           1       1
# 1                            0      1          1           0       0
# 2                            1      1          1           0       0
# 3                            0      4          1           2       0
# 4                            0      9          1           1       0
# ...                        ...    ...        ...         ...     ...
# 23875                        0      0          1           1       0
# 23876                        0      4          1           2       0
# 23877                        0     10          1           0       0
# 23878                        0      7          1           1       0
# 23879                        0      9          2           2       0
#
#        n_contact  n_month  n_poutcome
# 0              0        9           2
# 1              0        8           1
# 2              0        1           1
# 3              0        8           1
# 4              0        1           1
# ...          ...      ...         ...
# 23875          0        3           2
# 23876          0        6           1
# 23877          0        8           1
# 23878          0        1           1
# 23879          0        1           1
#
# [23524 rows x 24 columns]

# %%
df.drop(['job_type','month','marital','education','default','housing_loan','personal_loan','communication_type',
         'prev_campaign_outcome','customer_id'],axis=1,inplace=True)

# %%
df
# Out:
#        customer_age  balance  day_of_month  last_contact_duration  \
# 0              34.0    934.0            18                    704
# 1              41.0   1352.0            13                    893
# 2              57.0    495.0            18                    796
# 3              37.0    650.0            26                    880
# 4              29.0    265.0            19                    795
# ...             ...      ...           ...                    ...
# 23875          58.0    567.0             2                    993
# 23876          51.0   1072.0            20                    855
# 23877          41.0    242.0            23                    883
# 23878          48.0   2699.0            11                    803
# 23879          38.0   1045.0            18                    796
#
#        num_contacts_in_campaign  num_contacts_prev_campaign  \
# 0                           2.0                           1
# 1                           2.0                           0
# 2                           4.0                           0
# 3                           1.0                           0
# 4                           2.0                           0
# ...                         ...                         ...
# 23875                       2.0                           3
# 23876                       7.0                           0
# 23877                       2.0                           0
# 23878                       6.0                           0
# 23879                      10.0                           0
#
#        term_deposit_subscribed  n_job  n_marital  n_education  n_loan  \
# 0                            0      1          1            1       1
# 1                            0      1          1            0       0
# 2                            1      1          1            0       0
# 3                            0      4          1            2       0
# 4                            0      9          1            1       0
# ...                        ...    ...        ...          ...     ...
# 23875                        0      0          1            1       0
# 23876                        0      4          1            2       0
# 23877                        0     10          1            0       0
# 23878                        0      7          1            1       0
# 23879                        0      9          2            2       0
#
#        n_contact  n_month  n_poutcome
# 0              0        9           2
# 1              0        8           1
# 2              0        1           1
# 3              0        8           1
# 4              0        1           1
# ...          ...      ...         ...
# 23875          0        3           2
# 23876          0        6           1
# 23877          0        8           1
# 23878          0        1           1
# 23879          0        1           1
#
# [23524 rows x 14 columns]

# %%
for col in df.select_dtypes(include='int64').columns:
  print(col)
  print(df[col].unique())
# Out:
# day_of_month
# [18 13 26 19  7 16  6 17  5 22  2 20  3  4 29 30 14  9 27 31 23 12 11  8
#  15 25  1 28 21 10 24]
# last_contact_duration
# [ 704  893  796  880  795  807  899  920  989  857  705  870  869  823
#   843  794  842  841  997  933  996  888  892  751  816  774  858  916
#   879  814  730  894  895  898  992  891  990  820  901  863  702  792
#   801  834  752  951  788  782  991  877  837  829  876  866  817  740
#   900  871  670  677  785  824  675  855  808  902  889  913  872  859
#   761  809  883  830  986  706  887  998  919  936  827  789  929  873
#   897  701  885  825  793  878  890  906  803  815  703  886  802  853
#   828  963  728  800  950  836  806  874  754  909  838  850  733  864
#   969  786  923  810  993  922  958  787  881  835  984  662  822  968
#   856  965  812  762  724  710  833  725  711  935  735 1013  668  783
#   882  678  861  921  695  959  985  821  739  716  758  928  831  778
#   952  849  797  847  720  726  685  768  927  731  804  860  937  938
#   930  718  745  955  818  956  957  884  723  941  674 1012  766  776
#   852  943  775  747  777  977  742  760  732  727  976  779  914  934
#   756  832  848  736  773 1008  781  862  811  755  949  907  669  767
#   944  692 1001  917  844 1018  772 1011  770 1015 1019  738  910  999
#   769  734  790  688  845  867  709  980  813  972  729  994  690 1014
#   945  676  964  915  912  924  780  671  717  970  931  851  791  940
#   663  971  973  737  708  805  983  942  713  839  819  962  684  908
#   664  875  954  697  744  683  741  714  719  987  746  712  979 1000
#   763  707  759  689  978  846  682  798  698  854  840  765  868  753
#   661 1004  680  749  896  948  826  982  679  687  722  748  665  961
#   947  757  681  784]
# num_contacts_prev_campaign
# [  1   0   9   3   7   4   2   6   5  11  12  16  15   8  20  24  14  10
#   13  17  22  18  27  29  41 275  32  23  19  25  26  38  21  51  30  58
#   37  28]
# term_deposit_subscribed
# [0 1]

# %%
df.describe()
# Out:
#        customer_age       balance  day_of_month  last_contact_duration  \
# count  23524.000000  23524.000000  23524.000000           23524.000000
# mean      40.225047   1360.878599     15.800119             854.916638
# std       10.660200   3005.177283      8.319657              74.608798
# min       18.000000  -8020.000000      1.000000             661.000000
# 25%       32.000000     74.000000      8.000000             809.000000
# 50%       38.000000    455.500000     16.000000             871.000000
# 75%       48.000000   1413.250000     21.000000             897.000000
# max       93.000000  98419.000000     31.000000            1019.000000
#
#        num_contacts_in_campaign  num_contacts_prev_campaign  \
# count              23524.000000                23524.000000
# mean                   2.770405                    0.585402
# std                    3.133031                    2.637983
# min                    1.000000                    0.000000
# 25%                    1.000000                    0.000000
# 50%                    2.000000                    0.000000
# 75%                    3.000000                    0.000000
# max                   63.000000                  275.000000
#
#        term_deposit_subscribed         n_job     n_marital   n_education  \
# count             23524.000000  23524.000000  23524.000000  23524.000000
# mean                  0.106232      4.294253      1.164853      1.149379
# std                   0.308141      3.235169      0.611246      0.662715
# min                   0.000000      0.000000      0.000000      0.000000
# 25%                   0.000000      1.000000      1.000000      1.000000
# 50%                   0.000000      4.000000      1.000000      1.000000
# 75%                   0.000000      7.000000      2.000000      2.000000
# max                   1.000000     10.000000      2.000000      2.000000
#
#              n_loan     n_contact       n_month    n_poutcome
# count  23524.000000  23524.000000  23524.000000  23524.000000
# mean       0.159327      0.088123      5.538471      0.997024
# std        0.365988      0.283479      3.012283      0.532887
# min        0.000000      0.000000      0.000000      0.000000
# 25%        0.000000      0.000000      3.000000      1.000000
# 50%        0.000000      0.000000      6.000000      1.000000
# 75%        0.000000      0.000000      8.000000      1.000000
# max        1.000000      1.000000     11.000000      3.000000

# %% [markdown]
# ### Outlier Detection

# %%
figure, axis = plt.subplots(3, 4, figsize = (60,25))
sns.boxplot(x='term_deposit_subscribed',y='customer_age',data=df,ax=axis[0,0])
sns.boxplot(x='term_deposit_subscribed',y='balance',data=df,ax=axis[0,1])
sns.boxplot(x='term_deposit_subscribed',y='last_contact_duration',data=df,ax=axis[0,2])
sns.boxplot(x='term_deposit_subscribed',y='num_contacts_in_campaign',data=df,ax=axis[0,3])
sns.boxplot(x='term_deposit_subscribed',y='num_contacts_prev_campaign',data=df,ax=axis[1,0])
sns.boxplot(x='term_deposit_subscribed',y='n_job',data=df,ax=axis[1,1])
sns.boxplot(x='term_deposit_subscribed',y='n_marital',data=df,ax=axis[1,2])
sns.boxplot(x='term_deposit_subscribed',y='n_education',data=df,ax=axis[1,3])
sns.boxplot(x='term_deposit_subscribed',y='n_loan',data=df,ax=axis[2,0])
sns.boxplot(x='term_deposit_subscribed',y='n_contact',data=df,ax=axis[2,1])
sns.boxplot(x='term_deposit_subscribed',y='n_month',data=df,ax=axis[2,2])
sns.boxplot(x='term_deposit_subscribed',y='n_poutcome',data=df,ax=axis[2,3])
# Out:
# <AxesSubplot:xlabel='term_deposit_subscribed', ylabel='n_poutcome'>

# %%
outcome_zero=df[df['term_deposit_subscribed'] == 0]
outcome_zero
# Out:
#        customer_age  balance  day_of_month  last_contact_duration  \
# 0              34.0    934.0            18                    704
# 1              41.0   1352.0            13                    893
# 3              37.0    650.0            26                    880
# 4              29.0    265.0            19                    795
# 5              50.0    407.0             7                    807
# ...             ...      ...           ...                    ...
# 23875          58.0    567.0             2                    993
# 23876          51.0   1072.0            20                    855
# 23877          41.0    242.0            23                    883
# 23878          48.0   2699.0            11                    803
# 23879          38.0   1045.0            18                    796
#
#        num_contacts_in_campaign  num_contacts_prev_campaign  \
# 0                           2.0                           1
# 1                           2.0                           0
# 3                           1.0                           0
# 4                           2.0                           0
# 5                           2.0                           0
# ...                         ...                         ...
# 23875                       2.0                           3
# 23876                       7.0                           0
# 23877                       2.0                           0
# 23878                       6.0                           0
# 23879                      10.0                           0
#
#        term_deposit_subscribed  n_job  n_marital  n_education  n_loan  \
# 0                            0      1          1            1       1
# 1                            0      1          1            0       0
# 3                            0      4          1            2       0
# 4                            0      9          1            1       0
# 5                            0      1          1            1       1
# ...                        ...    ...        ...          ...     ...
# 23875                        0      0          1            1       0
# 23876                        0      4          1            2       0
# 23877                        0     10          1            0       0
# 23878                        0      7          1            1       0
# 23879                        0      9          2            2       0
#
#        n_contact  n_month  n_poutcome
# 0              0        9           2
# 1              0        8           1
# 3              0        8           1
# 4              0        1           1
# 5              0        1           1
# ...          ...      ...         ...
# 23875          0        3           2
# 23876          0        6           1
# 23877          0        8           1
# 23878          0        1           1
# 23879          0        1           1
#
# [21025 rows x 14 columns]

# %% [markdown]
# ### Outliers Removal

# %%
def Outdet(df):
    Q1=df.quantile(0.25)
    Q3=df.quantile(0.75)
    IQR=Q3-Q1
    LR=Q1-(IQR*1.5)
    UR=Q3+(IQR*1.5)
    return LR,UR

# %%
LR,UR=Outdet(outcome_zero.customer_age)
print(LR,UR)
# Out:
# 8.0 72.0

# %%
outcome_zero=outcome_zero[(outcome_zero['customer_age'] > LR)  &  (outcome_zero['customer_age'] < UR)]

# %%
outcome_zero
# Out:
#        customer_age  balance  day_of_month  last_contact_duration  \
# 0              34.0    934.0            18                    704
# 1              41.0   1352.0            13                    893
# 3              37.0    650.0            26                    880
# 4              29.0    265.0            19                    795
# 5              50.0    407.0             7                    807
# ...             ...      ...           ...                    ...
# 23875          58.0    567.0             2                    993
# 23876          51.0   1072.0            20                    855
# 23877          41.0    242.0            23                    883
# 23878          48.0   2699.0            11                    803
# 23879          38.0   1045.0            18                    796
#
#        num_contacts_in_campaign  num_contacts_prev_campaign  \
# 0                           2.0                           1
# 1                           2.0                           0
# 3                           1.0                           0
# 4                           2.0                           0
# 5                           2.0                           0
# ...                         ...                         ...
# 23875                       2.0                           3
# 23876                       7.0                           0
# 23877                       2.0                           0
# 23878                       6.0                           0
# 23879                      10.0                           0
#
#        term_deposit_subscribed  n_job  n_marital  n_education  n_loan  \
# 0                            0      1          1            1       1
# 1                            0      1          1            0       0
# 3                            0      4          1            2       0
# 4                            0      9          1            1       0
# 5                            0      1          1            1       1
# ...                        ...    ...        ...          ...     ...
# 23875                        0      0          1            1       0
# 23876                        0      4          1            2       0
# 23877                        0     10          1            0       0
# 23878                        0      7          1            1       0
# 23879                        0      9          2            2       0
#
#        n_contact  n_month  n_poutcome
# 0              0        9           2
# 1              0        8           1
# 3              0        8           1
# 4              0        1           1
# 5              0        1           1
# ...          ...      ...         ...
# 23875          0        3           2
# 23876          0        6           1
# 23877          0        8           1
# 23878          0        1           1
# 23879          0        1           1
#
# [20903 rows x 14 columns]

# %%
LR,UR=Outdet(outcome_zero.balance)
print(LR,UR)
# Out:
# -1852.5 3247.5

# %%
outcome_zero=outcome_zero[(outcome_zero['balance']>LR) & (outcome_zero['balance']< UR)]
outcome_zero
# Out:
#        customer_age  balance  day_of_month  last_contact_duration  \
# 0              34.0    934.0            18                    704
# 1              41.0   1352.0            13                    893
# 3              37.0    650.0            26                    880
# 4              29.0    265.0            19                    795
# 5              50.0    407.0             7                    807
# ...             ...      ...           ...                    ...
# 23875          58.0    567.0             2                    993
# 23876          51.0   1072.0            20                    855
# 23877          41.0    242.0            23                    883
# 23878          48.0   2699.0            11                    803
# 23879          38.0   1045.0            18                    796
#
#        num_contacts_in_campaign  num_contacts_prev_campaign  \
# 0                           2.0                           1
# 1                           2.0                           0
# 3                           1.0                           0
# 4                           2.0                           0
# 5                           2.0                           0
# ...                         ...                         ...
# 23875                       2.0                           3
# 23876                       7.0                           0
# 23877                       2.0                           0
# 23878                       6.0                           0
# 23879                      10.0                           0
#
#        term_deposit_subscribed  n_job  n_marital  n_education  n_loan  \
# 0                            0      1          1            1       1
# 1                            0      1          1            0       0
# 3                            0      4          1            2       0
# 4                            0      9          1            1       0
# 5                            0      1          1            1       1
# ...                        ...    ...        ...          ...     ...
# 23875                        0      0          1            1       0
# 23876                        0      4          1            2       0
# 23877                        0     10          1            0       0
# 23878                        0      7          1            1       0
# 23879                        0      9          2            2       0
#
#        n_contact  n_month  n_poutcome
# 0              0        9           2
# 1              0        8           1
# 3              0        8           1
# 4              0        1           1
# 5              0        1           1
# ...          ...      ...         ...
# 23875          0        3           2
# 23876          0        6           1
# 23877          0        8           1
# 23878          0        1           1
# 23879          0        1           1
#
# [18684 rows x 14 columns]

# %%
LR,UR=Outdet(outcome_zero.last_contact_duration)
print(LR,UR)
# Out:
# 692.0 1020.0

# %%
outcome_zero=outcome_zero[(outcome_zero['last_contact_duration']>LR) & (outcome_zero['last_contact_duration']< UR)]
outcome_zero
# Out:
#        customer_age  balance  day_of_month  last_contact_duration  \
# 0              34.0    934.0            18                    704
# 1              41.0   1352.0            13                    893
# 3              37.0    650.0            26                    880
# 4              29.0    265.0            19                    795
# 5              50.0    407.0             7                    807
# ...             ...      ...           ...                    ...
# 23875          58.0    567.0             2                    993
# 23876          51.0   1072.0            20                    855
# 23877          41.0    242.0            23                    883
# 23878          48.0   2699.0            11                    803
# 23879          38.0   1045.0            18                    796
#
#        num_contacts_in_campaign  num_contacts_prev_campaign  \
# 0                           2.0                           1
# 1                           2.0                           0
# 3                           1.0                           0
# 4                           2.0                           0
# 5                           2.0                           0
# ...                         ...                         ...
# 23875                       2.0                           3
# 23876                       7.0                           0
# 23877                       2.0                           0
# 23878                       6.0                           0
# 23879                      10.0                           0
#
#        term_deposit_subscribed  n_job  n_marital  n_education  n_loan  \
# 0                            0      1          1            1       1
# 1                            0      1          1            0       0
# 3                            0      4          1            2       0
# 4                            0      9          1            1       0
# 5                            0      1          1            1       1
# ...                        ...    ...        ...          ...     ...
# 23875                        0      0          1            1       0
# 23876                        0      4          1            2       0
# 23877                        0     10          1            0       0
# 23878                        0      7          1            1       0
# 23879                        0      9          2            2       0
#
#        n_contact  n_month  n_poutcome
# 0              0        9           2
# 1              0        8           1
# 3              0        8           1
# 4              0        1           1
# 5              0        1           1
# ...          ...      ...         ...
# 23875          0        3           2
# 23876          0        6           1
# 23877          0        8           1
# 23878          0        1           1
# 23879          0        1           1
#
# [18627 rows x 14 columns]

# %%
LR,UR=Outdet(outcome_zero.num_contacts_in_campaign)
print(LR,UR)
# Out:
# -2.0 6.0

# %%
outcome_zero=outcome_zero[(outcome_zero['num_contacts_in_campaign']>LR) & (outcome_zero['num_contacts_in_campaign']< UR)]
outcome_zero
# Out:
#        customer_age  balance  day_of_month  last_contact_duration  \
# 0              34.0    934.0            18                    704
# 1              41.0   1352.0            13                    893
# 3              37.0    650.0            26                    880
# 4              29.0    265.0            19                    795
# 5              50.0    407.0             7                    807
# ...             ...      ...           ...                    ...
# 23870          35.0    662.0            19                    703
# 23872          45.0     92.0            17                    919
# 23873          40.0      2.0             2                    993
# 23875          58.0    567.0             2                    993
# 23877          41.0    242.0            23                    883
#
#        num_contacts_in_campaign  num_contacts_prev_campaign  \
# 0                           2.0                           1
# 1                           2.0                           0
# 3                           1.0                           0
# 4                           2.0                           0
# 5                           2.0                           0
# ...                         ...                         ...
# 23870                       1.0                           0
# 23872                       2.0                           1
# 23873                       4.0                           0
# 23875                       2.0                           3
# 23877                       2.0                           0
#
#        term_deposit_subscribed  n_job  n_marital  n_education  n_loan  \
# 0                            0      1          1            1       1
# 1                            0      1          1            0       0
# 3                            0      4          1            2       0
# 4                            0      9          1            1       0
# 5                            0      1          1            1       1
# ...                        ...    ...        ...          ...     ...
# 23870                        0      4          2            2       0
# 23872                        0      7          0            0       0
# 23873                        0      2          1            2       1
# 23875                        0      0          1            1       0
# 23877                        0     10          1            0       0
#
#        n_contact  n_month  n_poutcome
# 0              0        9           2
# 1              0        8           1
# 3              0        8           1
# 4              0        1           1
# 5              0        1           1
# ...          ...      ...         ...
# 23870          0        9           1
# 23872          0        0           0
# 23873          0        3           1
# 23875          0        3           2
# 23877          0        8           1
#
# [16710 rows x 14 columns]

# %%
outcome_one=df[df['term_deposit_subscribed'] == 1]
outcome_one
# Out:
#        customer_age  balance  day_of_month  last_contact_duration  \
# 2              57.0    495.0            18                    796
# 7              18.0    420.0            16                    920
# 16             70.0    479.0             2                    843
# 19             28.0    340.0             4                    841
# 26             54.0   1459.0             2                    751
# ...             ...      ...           ...                    ...
# 23823          33.0    542.0            16                    920
# 23829          47.0    127.0             3                    872
# 23831          32.0   5612.0            28                    817
# 23842          27.0    614.0            18                    888
# 23874          51.0    298.0            15                    891
#
#        num_contacts_in_campaign  num_contacts_prev_campaign  \
# 2                           4.0                           0
# 7                           1.0                           0
# 16                          2.0                           0
# 19                          3.0                           0
# 26                          2.0                           1
# ...                         ...                         ...
# 23823                       1.0                           4
# 23829                       2.0                           0
# 23831                       3.0                           0
# 23842                       1.0                           0
# 23874                       4.0                           1
#
#        term_deposit_subscribed  n_job  n_marital  n_education  n_loan  \
# 2                            1      1          1            0       0
# 7                            1      1          2            1       0
# 16                           1      5          0            0       0
# 19                           1      7          2            0       0
# 26                           1      4          1            2       0
# ...                        ...    ...        ...          ...     ...
# 23823                        1      9          1            1       0
# 23829                        1      1          0            0       0
# 23831                        1      6          1            1       0
# 23842                        1      9          2            2       0
# 23874                        1      4          2            2       0
#
#        n_contact  n_month  n_poutcome
# 2              0        1           1
# 7              0        0           1
# 16             0        5           1
# 19             0        5           1
# 26             0       10           3
# ...          ...      ...         ...
# 23823          0        0           0
# 23829          0        6           1
# 23831          0        5           1
# 23842          0        8           1
# 23874          0        8           0
#
# [2499 rows x 14 columns]

# %%
LR,UR=Outdet(outcome_one.customer_age)
print(LR,UR)
# Out:
# 2.5 78.5

# %%
outcome_one=outcome_one[(outcome_one['customer_age'] > LR)  &  (outcome_one['customer_age'] < UR)]
outcome_one
# Out:
#        customer_age  balance  day_of_month  last_contact_duration  \
# 2              57.0    495.0            18                    796
# 7              18.0    420.0            16                    920
# 16             70.0    479.0             2                    843
# 19             28.0    340.0             4                    841
# 26             54.0   1459.0             2                    751
# ...             ...      ...           ...                    ...
# 23823          33.0    542.0            16                    920
# 23829          47.0    127.0             3                    872
# 23831          32.0   5612.0            28                    817
# 23842          27.0    614.0            18                    888
# 23874          51.0    298.0            15                    891
#
#        num_contacts_in_campaign  num_contacts_prev_campaign  \
# 2                           4.0                           0
# 7                           1.0                           0
# 16                          2.0                           0
# 19                          3.0                           0
# 26                          2.0                           1
# ...                         ...                         ...
# 23823                       1.0                           4
# 23829                       2.0                           0
# 23831                       3.0                           0
# 23842                       1.0                           0
# 23874                       4.0                           1
#
#        term_deposit_subscribed  n_job  n_marital  n_education  n_loan  \
# 2                            1      1          1            0       0
# 7                            1      1          2            1       0
# 16                           1      5          0            0       0
# 19                           1      7          2            0       0
# 26                           1      4          1            2       0
# ...                        ...    ...        ...          ...     ...
# 23823                        1      9          1            1       0
# 23829                        1      1          0            0       0
# 23831                        1      6          1            1       0
# 23842                        1      9          2            2       0
# 23874                        1      4          2            2       0
#
#        n_contact  n_month  n_poutcome
# 2              0        1           1
# 7              0        0           1
# 16             0        5           1
# 19             0        5           1
# 26             0       10           3
# ...          ...      ...         ...
# 23823          0        0           0
# 23829          0        6           1
# 23831          0        5           1
# 23842          0        8           1
# 23874          0        8           0
#
# [2472 rows x 14 columns]

# %%
LR,UR=Outdet(outcome_one.balance)
print(LR,UR)
# Out:
# -2688.25 5063.75

# %%
outcome_one=outcome_one[(outcome_one['balance']>LR) & (outcome_one['balance']< UR)]
outcome_one
# Out:
#        customer_age  balance  day_of_month  last_contact_duration  \
# 2              57.0    495.0            18                    796
# 7              18.0    420.0            16                    920
# 16             70.0    479.0             2                    843
# 19             28.0    340.0             4                    841
# 26             54.0   1459.0             2                    751
# ...             ...      ...           ...                    ...
# 23811          41.0    701.0            20                    702
# 23823          33.0    542.0            16                    920
# 23829          47.0    127.0             3                    872
# 23842          27.0    614.0            18                    888
# 23874          51.0    298.0            15                    891
#
#        num_contacts_in_campaign  num_contacts_prev_campaign  \
# 2                           4.0                           0
# 7                           1.0                           0
# 16                          2.0                           0
# 19                          3.0                           0
# 26                          2.0                           1
# ...                         ...                         ...
# 23811                       2.0                           2
# 23823                       1.0                           4
# 23829                       2.0                           0
# 23842                       1.0                           0
# 23874                       4.0                           1
#
#        term_deposit_subscribed  n_job  n_marital  n_education  n_loan  \
# 2                            1      1          1            0       0
# 7                            1      1          2            1       0
# 16                           1      5          0            0       0
# 19                           1      7          2            0       0
# 26                           1      4          1            2       0
# ...                        ...    ...        ...          ...     ...
# 23811                        1      1          1            1       1
# 23823                        1      9          1            1       0
# 23829                        1      1          0            0       0
# 23842                        1      9          2            2       0
# 23874                        1      4          2            2       0
#
#        n_contact  n_month  n_poutcome
# 2              0        1           1
# 7              0        0           1
# 16             0        5           1
# 19             0        5           1
# 26             0       10           3
# ...          ...      ...         ...
# 23811          0        9           2
# 23823          0        0           0
# 23829          0        6           1
# 23842          0        8           1
# 23874          0        8           0
#
# [2265 rows x 14 columns]

# %%
LR,UR=Outdet(outcome_one.last_contact_duration)
print(LR,UR)
# Out:
# 631.0 1071.0

# %%
outcome_one=outcome_one[(outcome_one['last_contact_duration']>LR) & (outcome_one['last_contact_duration']< UR)]
outcome_one
# Out:
#        customer_age  balance  day_of_month  last_contact_duration  \
# 2              57.0    495.0            18                    796
# 7              18.0    420.0            16                    920
# 16             70.0    479.0             2                    843
# 19             28.0    340.0             4                    841
# 26             54.0   1459.0             2                    751
# ...             ...      ...           ...                    ...
# 23811          41.0    701.0            20                    702
# 23823          33.0    542.0            16                    920
# 23829          47.0    127.0             3                    872
# 23842          27.0    614.0            18                    888
# 23874          51.0    298.0            15                    891
#
#        num_contacts_in_campaign  num_contacts_prev_campaign  \
# 2                           4.0                           0
# 7                           1.0                           0
# 16                          2.0                           0
# 19                          3.0                           0
# 26                          2.0                           1
# ...                         ...                         ...
# 23811                       2.0                           2
# 23823                       1.0                           4
# 23829                       2.0                           0
# 23842                       1.0                           0
# 23874                       4.0                           1
#
#        term_deposit_subscribed  n_job  n_marital  n_education  n_loan  \
# 2                            1      1          1            0       0
# 7                            1      1          2            1       0
# 16                           1      5          0            0       0
# 19                           1      7          2            0       0
# 26                           1      4          1            2       0
# ...                        ...    ...        ...          ...     ...
# 23811                        1      1          1            1       1
# 23823                        1      9          1            1       0
# 23829                        1      1          0            0       0
# 23842                        1      9          2            2       0
# 23874                        1      4          2            2       0
#
#        n_contact  n_month  n_poutcome
# 2              0        1           1
# 7              0        0           1
# 16             0        5           1
# 19             0        5           1
# 26             0       10           3
# ...          ...      ...         ...
# 23811          0        9           2
# 23823          0        0           0
# 23829          0        6           1
# 23842          0        8           1
# 23874          0        8           0
#
# [2265 rows x 14 columns]

# %%
LR,UR=Outdet(outcome_one.num_contacts_in_campaign)
print(LR,UR)
# Out:
# -2.0 6.0

# %%
outcome_one=outcome_one[(outcome_one['num_contacts_in_campaign']>LR) & (outcome_one['num_contacts_in_campaign']< UR)]
outcome_one
# Out:
#        customer_age  balance  day_of_month  last_contact_duration  \
# 2              57.0    495.0            18                    796
# 7              18.0    420.0            16                    920
# 16             70.0    479.0             2                    843
# 19             28.0    340.0             4                    841
# 26             54.0   1459.0             2                    751
# ...             ...      ...           ...                    ...
# 23811          41.0    701.0            20                    702
# 23823          33.0    542.0            16                    920
# 23829          47.0    127.0             3                    872
# 23842          27.0    614.0            18                    888
# 23874          51.0    298.0            15                    891
#
#        num_contacts_in_campaign  num_contacts_prev_campaign  \
# 2                           4.0                           0
# 7                           1.0                           0
# 16                          2.0                           0
# 19                          3.0                           0
# 26                          2.0                           1
# ...                         ...                         ...
# 23811                       2.0                           2
# 23823                       1.0                           4
# 23829                       2.0                           0
# 23842                       1.0                           0
# 23874                       4.0                           1
#
#        term_deposit_subscribed  n_job  n_marital  n_education  n_loan  \
# 2                            1      1          1            0       0
# 7                            1      1          2            1       0
# 16                           1      5          0            0       0
# 19                           1      7          2            0       0
# 26                           1      4          1            2       0
# ...                        ...    ...        ...          ...     ...
# 23811                        1      1          1            1       1
# 23823                        1      9          1            1       0
# 23829                        1      1          0            0       0
# 23842                        1      9          2            2       0
# 23874                        1      4          2            2       0
#
#        n_contact  n_month  n_poutcome
# 2              0        1           1
# 7              0        0           1
# 16             0        5           1
# 19             0        5           1
# 26             0       10           3
# ...          ...      ...         ...
# 23811          0        9           2
# 23823          0        0           0
# 23829          0        6           1
# 23842          0        8           1
# 23874          0        8           0
#
# [2166 rows x 14 columns]

# %%
LR,UR=Outdet(outcome_one.balance)
print(LR,UR)
outcome_one=outcome_one[(outcome_one['balance']>LR) & (outcome_one['balance']< UR)]
outcome_one
# Out:
# -2018.625 3844.375
#        customer_age  balance  day_of_month  last_contact_duration  \
# 2              57.0    495.0            18                    796
# 7              18.0    420.0            16                    920
# 16             70.0    479.0             2                    843
# 19             28.0    340.0             4                    841
# 26             54.0   1459.0             2                    751
# ...             ...      ...           ...                    ...
# 23811          41.0    701.0            20                    702
# 23823          33.0    542.0            16                    920
# 23829          47.0    127.0             3                    872
# 23842          27.0    614.0            18                    888
# 23874          51.0    298.0            15                    891
#
#        num_contacts_in_campaign  num_contacts_prev_campaign  \
# 2                           4.0                           0
# 7                           1.0                           0
# 16                          2.0                           0
# 19                          3.0                           0
# 26                          2.0                           1
# ...                         ...                         ...
# 23811                       2.0                           2
# 23823                       1.0                           4
# 23829                       2.0                           0
# 23842                       1.0                           0
# 23874                       4.0                           1
#
#        term_deposit_subscribed  n_job  n_marital  n_education  n_loan  \
# 2                            1      1          1            0       0
# 7                            1      1          2            1       0
# 16                           1      5          0            0       0
# 19                           1      7          2            0       0
# 26                           1      4          1            2       0
# ...                        ...    ...        ...          ...     ...
# 23811                        1      1          1            1       1
# 23823                        1      9          1            1       0
# 23829                        1      1          0            0       0
# 23842                        1      9          2            2       0
# 23874                        1      4          2            2       0
#
#        n_contact  n_month  n_poutcome
# 2              0        1           1
# 7              0        0           1
# 16             0        5           1
# 19             0        5           1
# 26             0       10           3
# ...          ...      ...         ...
# 23811          0        9           2
# 23823          0        0           0
# 23829          0        6           1
# 23842          0        8           1
# 23874          0        8           0
#
# [2067 rows x 14 columns]

# %%
LR,UR=Outdet(outcome_zero.balance)
print(LR,UR)
outcome_zero=outcome_zero[(outcome_zero['balance']>LR) & (outcome_zero['balance']< UR)]
outcome_zero
# Out:
# -1308.125 2278.875
#        customer_age  balance  day_of_month  last_contact_duration  \
# 0              34.0    934.0            18                    704
# 1              41.0   1352.0            13                    893
# 3              37.0    650.0            26                    880
# 4              29.0    265.0            19                    795
# 5              50.0    407.0             7                    807
# ...             ...      ...           ...                    ...
# 23870          35.0    662.0            19                    703
# 23872          45.0     92.0            17                    919
# 23873          40.0      2.0             2                    993
# 23875          58.0    567.0             2                    993
# 23877          41.0    242.0            23                    883
#
#        num_contacts_in_campaign  num_contacts_prev_campaign  \
# 0                           2.0                           1
# 1                           2.0                           0
# 3                           1.0                           0
# 4                           2.0                           0
# 5                           2.0                           0
# ...                         ...                         ...
# 23870                       1.0                           0
# 23872                       2.0                           1
# 23873                       4.0                           0
# 23875                       2.0                           3
# 23877                       2.0                           0
#
#        term_deposit_subscribed  n_job  n_marital  n_education  n_loan  \
# 0                            0      1          1            1       1
# 1                            0      1          1            0       0
# 3                            0      4          1            2       0
# 4                            0      9          1            1       0
# 5                            0      1          1            1       1
# ...                        ...    ...        ...          ...     ...
# 23870                        0      4          2            2       0
# 23872                        0      7          0            0       0
# 23873                        0      2          1            2       1
# 23875                        0      0          1            1       0
# 23877                        0     10          1            0       0
#
#        n_contact  n_month  n_poutcome
# 0              0        9           2
# 1              0        8           1
# 3              0        8           1
# 4              0        1           1
# 5              0        1           1
# ...          ...      ...         ...
# 23870          0        9           1
# 23872          0        0           0
# 23873          0        3           1
# 23875          0        3           2
# 23877          0        8           1
#
# [15761 rows x 14 columns]

# %%
LR,UR=Outdet(outcome_one.balance)
print(LR,UR)
outcome_one=outcome_one[(outcome_one['balance']>LR) & (outcome_one['balance']< UR)]
outcome_one
# Out:
# -1728.25 3301.75
#        customer_age  balance  day_of_month  last_contact_duration  \
# 2              57.0    495.0            18                    796
# 7              18.0    420.0            16                    920
# 16             70.0    479.0             2                    843
# 19             28.0    340.0             4                    841
# 26             54.0   1459.0             2                    751
# ...             ...      ...           ...                    ...
# 23811          41.0    701.0            20                    702
# 23823          33.0    542.0            16                    920
# 23829          47.0    127.0             3                    872
# 23842          27.0    614.0            18                    888
# 23874          51.0    298.0            15                    891
#
#        num_contacts_in_campaign  num_contacts_prev_campaign  \
# 2                           4.0                           0
# 7                           1.0                           0
# 16                          2.0                           0
# 19                          3.0                           0
# 26                          2.0                           1
# ...                         ...                         ...
# 23811                       2.0                           2
# 23823                       1.0                           4
# 23829                       2.0                           0
# 23842                       1.0                           0
# 23874                       4.0                           1
#
#        term_deposit_subscribed  n_job  n_marital  n_education  n_loan  \
# 2                            1      1          1            0       0
# 7                            1      1          2            1       0
# 16                           1      5          0            0       0
# 19                           1      7          2            0       0
# 26                           1      4          1            2       0
# ...                        ...    ...        ...          ...     ...
# 23811                        1      1          1            1       1
# 23823                        1      9          1            1       0
# 23829                        1      1          0            0       0
# 23842                        1      9          2            2       0
# 23874                        1      4          2            2       0
#
#        n_contact  n_month  n_poutcome
# 2              0        1           1
# 7              0        0           1
# 16             0        5           1
# 19             0        5           1
# 26             0       10           3
# ...          ...      ...         ...
# 23811          0        9           2
# 23823          0        0           0
# 23829          0        6           1
# 23842          0        8           1
# 23874          0        8           0
#
# [1984 rows x 14 columns]

# %%
LR,UR=Outdet(outcome_one.balance)
print(LR,UR)
outcome_one=outcome_one[(outcome_one['balance']>LR) & (outcome_one['balance']< UR)]
outcome_one
# Out:
# -1549.25 2970.75
#        customer_age  balance  day_of_month  last_contact_duration  \
# 2              57.0    495.0            18                    796
# 7              18.0    420.0            16                    920
# 16             70.0    479.0             2                    843
# 19             28.0    340.0             4                    841
# 26             54.0   1459.0             2                    751
# ...             ...      ...           ...                    ...
# 23811          41.0    701.0            20                    702
# 23823          33.0    542.0            16                    920
# 23829          47.0    127.0             3                    872
# 23842          27.0    614.0            18                    888
# 23874          51.0    298.0            15                    891
#
#        num_contacts_in_campaign  num_contacts_prev_campaign  \
# 2                           4.0                           0
# 7                           1.0                           0
# 16                          2.0                           0
# 19                          3.0                           0
# 26                          2.0                           1
# ...                         ...                         ...
# 23811                       2.0                           2
# 23823                       1.0                           4
# 23829                       2.0                           0
# 23842                       1.0                           0
# 23874                       4.0                           1
#
#        term_deposit_subscribed  n_job  n_marital  n_education  n_loan  \
# 2                            1      1          1            0       0
# 7                            1      1          2            1       0
# 16                           1      5          0            0       0
# 19                           1      7          2            0       0
# 26                           1      4          1            2       0
# ...                        ...    ...        ...          ...     ...
# 23811                        1      1          1            1       1
# 23823                        1      9          1            1       0
# 23829                        1      1          0            0       0
# 23842                        1      9          2            2       0
# 23874                        1      4          2            2       0
#
#        n_contact  n_month  n_poutcome
# 2              0        1           1
# 7              0        0           1
# 16             0        5           1
# 19             0        5           1
# 26             0       10           3
# ...          ...      ...         ...
# 23811          0        9           2
# 23823          0        0           0
# 23829          0        6           1
# 23842          0        8           1
# 23874          0        8           0
#
# [1934 rows x 14 columns]

# %%
LR,UR=Outdet(outcome_zero.balance)
print(LR,UR)
outcome_zero=outcome_zero[(outcome_zero['balance']>LR) & (outcome_zero['balance']< UR)]
outcome_zero
# Out:
# -1106.5 1913.5
#        customer_age  balance  day_of_month  last_contact_duration  \
# 0              34.0    934.0            18                    704
# 1              41.0   1352.0            13                    893
# 3              37.0    650.0            26                    880
# 4              29.0    265.0            19                    795
# 5              50.0    407.0             7                    807
# ...             ...      ...           ...                    ...
# 23870          35.0    662.0            19                    703
# 23872          45.0     92.0            17                    919
# 23873          40.0      2.0             2                    993
# 23875          58.0    567.0             2                    993
# 23877          41.0    242.0            23                    883
#
#        num_contacts_in_campaign  num_contacts_prev_campaign  \
# 0                           2.0                           1
# 1                           2.0                           0
# 3                           1.0                           0
# 4                           2.0                           0
# 5                           2.0                           0
# ...                         ...                         ...
# 23870                       1.0                           0
# 23872                       2.0                           1
# 23873                       4.0                           0
# 23875                       2.0                           3
# 23877                       2.0                           0
#
#        term_deposit_subscribed  n_job  n_marital  n_education  n_loan  \
# 0                            0      1          1            1       1
# 1                            0      1          1            0       0
# 3                            0      4          1            2       0
# 4                            0      9          1            1       0
# 5                            0      1          1            1       1
# ...                        ...    ...        ...          ...     ...
# 23870                        0      4          2            2       0
# 23872                        0      7          0            0       0
# 23873                        0      2          1            2       1
# 23875                        0      0          1            1       0
# 23877                        0     10          1            0       0
#
#        n_contact  n_month  n_poutcome
# 0              0        9           2
# 1              0        8           1
# 3              0        8           1
# 4              0        1           1
# 5              0        1           1
# ...          ...      ...         ...
# 23870          0        9           1
# 23872          0        0           0
# 23873          0        3           1
# 23875          0        3           2
# 23877          0        8           1
#
# [15225 rows x 14 columns]

# %%
LR,UR=Outdet(outcome_zero.balance)
print(LR,UR)
outcome_zero=outcome_zero[(outcome_zero['balance']>LR) & (outcome_zero['balance']< UR)]
outcome_zero
# Out:
# -1008.5 1739.5
#        customer_age  balance  day_of_month  last_contact_duration  \
# 0              34.0    934.0            18                    704
# 1              41.0   1352.0            13                    893
# 3              37.0    650.0            26                    880
# 4              29.0    265.0            19                    795
# 5              50.0    407.0             7                    807
# ...             ...      ...           ...                    ...
# 23870          35.0    662.0            19                    703
# 23872          45.0     92.0            17                    919
# 23873          40.0      2.0             2                    993
# 23875          58.0    567.0             2                    993
# 23877          41.0    242.0            23                    883
#
#        num_contacts_in_campaign  num_contacts_prev_campaign  \
# 0                           2.0                           1
# 1                           2.0                           0
# 3                           1.0                           0
# 4                           2.0                           0
# 5                           2.0                           0
# ...                         ...                         ...
# 23870                       1.0                           0
# 23872                       2.0                           1
# 23873                       4.0                           0
# 23875                       2.0                           3
# 23877                       2.0                           0
#
#        term_deposit_subscribed  n_job  n_marital  n_education  n_loan  \
# 0                            0      1          1            1       1
# 1                            0      1          1            0       0
# 3                            0      4          1            2       0
# 4                            0      9          1            1       0
# 5                            0      1          1            1       1
# ...                        ...    ...        ...          ...     ...
# 23870                        0      4          2            2       0
# 23872                        0      7          0            0       0
# 23873                        0      2          1            2       1
# 23875                        0      0          1            1       0
# 23877                        0     10          1            0       0
#
#        n_contact  n_month  n_poutcome
# 0              0        9           2
# 1              0        8           1
# 3              0        8           1
# 4              0        1           1
# 5              0        1           1
# ...          ...      ...         ...
# 23870          0        9           1
# 23872          0        0           0
# 23873          0        3           1
# 23875          0        3           2
# 23877          0        8           1
#
# [14903 rows x 14 columns]

# %%
LR,UR=Outdet(outcome_one.balance)
print(LR,UR)
outcome_one=outcome_one[(outcome_one['balance']>LR) & (outcome_one['balance']< UR)]
outcome_one
# Out:
# -1495.625 2847.375
#        customer_age  balance  day_of_month  last_contact_duration  \
# 2              57.0    495.0            18                    796
# 7              18.0    420.0            16                    920
# 16             70.0    479.0             2                    843
# 19             28.0    340.0             4                    841
# 26             54.0   1459.0             2                    751
# ...             ...      ...           ...                    ...
# 23811          41.0    701.0            20                    702
# 23823          33.0    542.0            16                    920
# 23829          47.0    127.0             3                    872
# 23842          27.0    614.0            18                    888
# 23874          51.0    298.0            15                    891
#
#        num_contacts_in_campaign  num_contacts_prev_campaign  \
# 2                           4.0                           0
# 7                           1.0                           0
# 16                          2.0                           0
# 19                          3.0                           0
# 26                          2.0                           1
# ...                         ...                         ...
# 23811                       2.0                           2
# 23823                       1.0                           4
# 23829                       2.0                           0
# 23842                       1.0                           0
# 23874                       4.0                           1
#
#        term_deposit_subscribed  n_job  n_marital  n_education  n_loan  \
# 2                            1      1          1            0       0
# 7                            1      1          2            1       0
# 16                           1      5          0            0       0
# 19                           1      7          2            0       0
# 26                           1      4          1            2       0
# ...                        ...    ...        ...          ...     ...
# 23811                        1      1          1            1       1
# 23823                        1      9          1            1       0
# 23829                        1      1          0            0       0
# 23842                        1      9          2            2       0
# 23874                        1      4          2            2       0
#
#        n_contact  n_month  n_poutcome
# 2              0        1           1
# 7              0        0           1
# 16             0        5           1
# 19             0        5           1
# 26             0       10           3
# ...          ...      ...         ...
# 23811          0        9           2
# 23823          0        0           0
# 23829          0        6           1
# 23842          0        8           1
# 23874          0        8           0
#
# [1913 rows x 14 columns]

# %%
LR,UR=Outdet(outcome_zero.balance)
print(LR,UR)
outcome_zero=outcome_zero[(outcome_zero['balance']>LR) & (outcome_zero['balance']< UR)]
outcome_zero
# Out:
# -965.0 1659.0
#        customer_age  balance  day_of_month  last_contact_duration  \
# 0              34.0    934.0            18                    704
# 1              41.0   1352.0            13                    893
# 3              37.0    650.0            26                    880
# 4              29.0    265.0            19                    795
# 5              50.0    407.0             7                    807
# ...             ...      ...           ...                    ...
# 23870          35.0    662.0            19                    703
# 23872          45.0     92.0            17                    919
# 23873          40.0      2.0             2                    993
# 23875          58.0    567.0             2                    993
# 23877          41.0    242.0            23                    883
#
#        num_contacts_in_campaign  num_contacts_prev_campaign  \
# 0                           2.0                           1
# 1                           2.0                           0
# 3                           1.0                           0
# 4                           2.0                           0
# 5                           2.0                           0
# ...                         ...                         ...
# 23870                       1.0                           0
# 23872                       2.0                           1
# 23873                       4.0                           0
# 23875                       2.0                           3
# 23877                       2.0                           0
#
#        term_deposit_subscribed  n_job  n_marital  n_education  n_loan  \
# 0                            0      1          1            1       1
# 1                            0      1          1            0       0
# 3                            0      4          1            2       0
# 4                            0      9          1            1       0
# 5                            0      1          1            1       1
# ...                        ...    ...        ...          ...     ...
# 23870                        0      4          2            2       0
# 23872                        0      7          0            0       0
# 23873                        0      2          1            2       1
# 23875                        0      0          1            1       0
# 23877                        0     10          1            0       0
#
#        n_contact  n_month  n_poutcome
# 0              0        9           2
# 1              0        8           1
# 3              0        8           1
# 4              0        1           1
# 5              0        1           1
# ...          ...      ...         ...
# 23870          0        9           1
# 23872          0        0           0
# 23873          0        3           1
# 23875          0        3           2
# 23877          0        8           1
#
# [14734 rows x 14 columns]

# %%
LR,UR=Outdet(outcome_one.balance)
print(LR,UR)
outcome_one=outcome_one[(outcome_one['balance']>LR) & (outcome_one['balance']< UR)]
outcome_one
# Out:
# -1443.0 2757.0
#        customer_age  balance  day_of_month  last_contact_duration  \
# 2              57.0    495.0            18                    796
# 7              18.0    420.0            16                    920
# 16             70.0    479.0             2                    843
# 19             28.0    340.0             4                    841
# 26             54.0   1459.0             2                    751
# ...             ...      ...           ...                    ...
# 23811          41.0    701.0            20                    702
# 23823          33.0    542.0            16                    920
# 23829          47.0    127.0             3                    872
# 23842          27.0    614.0            18                    888
# 23874          51.0    298.0            15                    891
#
#        num_contacts_in_campaign  num_contacts_prev_campaign  \
# 2                           4.0                           0
# 7                           1.0                           0
# 16                          2.0                           0
# 19                          3.0                           0
# 26                          2.0                           1
# ...                         ...                         ...
# 23811                       2.0                           2
# 23823                       1.0                           4
# 23829                       2.0                           0
# 23842                       1.0                           0
# 23874                       4.0                           1
#
#        term_deposit_subscribed  n_job  n_marital  n_education  n_loan  \
# 2                            1      1          1            0       0
# 7                            1      1          2            1       0
# 16                           1      5          0            0       0
# 19                           1      7          2            0       0
# 26                           1      4          1            2       0
# ...                        ...    ...        ...          ...     ...
# 23811                        1      1          1            1       1
# 23823                        1      9          1            1       0
# 23829                        1      1          0            0       0
# 23842                        1      9          2            2       0
# 23874                        1      4          2            2       0
#
#        n_contact  n_month  n_poutcome
# 2              0        1           1
# 7              0        0           1
# 16             0        5           1
# 19             0        5           1
# 26             0       10           3
# ...          ...      ...         ...
# 23811          0        9           2
# 23823          0        0           0
# 23829          0        6           1
# 23842          0        8           1
# 23874          0        8           0
#
# [1896 rows x 14 columns]

# %%
LR,UR=Outdet(outcome_zero.balance)
print(LR,UR)
outcome_zero=outcome_zero[(outcome_zero['balance']>LR) & (outcome_zero['balance']< UR)]
outcome_zero
# Out:
# -944.625 1622.375
#        customer_age  balance  day_of_month  last_contact_duration  \
# 0              34.0    934.0            18                    704
# 1              41.0   1352.0            13                    893
# 3              37.0    650.0            26                    880
# 4              29.0    265.0            19                    795
# 5              50.0    407.0             7                    807
# ...             ...      ...           ...                    ...
# 23870          35.0    662.0            19                    703
# 23872          45.0     92.0            17                    919
# 23873          40.0      2.0             2                    993
# 23875          58.0    567.0             2                    993
# 23877          41.0    242.0            23                    883
#
#        num_contacts_in_campaign  num_contacts_prev_campaign  \
# 0                           2.0                           1
# 1                           2.0                           0
# 3                           1.0                           0
# 4                           2.0                           0
# 5                           2.0                           0
# ...                         ...                         ...
# 23870                       1.0                           0
# 23872                       2.0                           1
# 23873                       4.0                           0
# 23875                       2.0                           3
# 23877                       2.0                           0
#
#        term_deposit_subscribed  n_job  n_marital  n_education  n_loan  \
# 0                            0      1          1            1       1
# 1                            0      1          1            0       0
# 3                            0      4          1            2       0
# 4                            0      9          1            1       0
# 5                            0      1          1            1       1
# ...                        ...    ...        ...          ...     ...
# 23870                        0      4          2            2       0
# 23872                        0      7          0            0       0
# 23873                        0      2          1            2       1
# 23875                        0      0          1            1       0
# 23877                        0     10          1            0       0
#
#        n_contact  n_month  n_poutcome
# 0              0        9           2
# 1              0        8           1
# 3              0        8           1
# 4              0        1           1
# 5              0        1           1
# ...          ...      ...         ...
# 23870          0        9           1
# 23872          0        0           0
# 23873          0        3           1
# 23875          0        3           2
# 23877          0        8           1
#
# [14661 rows x 14 columns]

# %%
LR,UR=Outdet(outcome_zero.customer_age)
print(LR,UR)
outcome_zero=outcome_zero[(outcome_zero['customer_age']>LR) & (outcome_zero['customer_age']< UR)]
outcome_zero
# Out:
# 11.0 67.0
#        customer_age  balance  day_of_month  last_contact_duration  \
# 0              34.0    934.0            18                    704
# 1              41.0   1352.0            13                    893
# 3              37.0    650.0            26                    880
# 4              29.0    265.0            19                    795
# 5              50.0    407.0             7                    807
# ...             ...      ...           ...                    ...
# 23870          35.0    662.0            19                    703
# 23872          45.0     92.0            17                    919
# 23873          40.0      2.0             2                    993
# 23875          58.0    567.0             2                    993
# 23877          41.0    242.0            23                    883
#
#        num_contacts_in_campaign  num_contacts_prev_campaign  \
# 0                           2.0                           1
# 1                           2.0                           0
# 3                           1.0                           0
# 4                           2.0                           0
# 5                           2.0                           0
# ...                         ...                         ...
# 23870                       1.0                           0
# 23872                       2.0                           1
# 23873                       4.0                           0
# 23875                       2.0                           3
# 23877                       2.0                           0
#
#        term_deposit_subscribed  n_job  n_marital  n_education  n_loan  \
# 0                            0      1          1            1       1
# 1                            0      1          1            0       0
# 3                            0      4          1            2       0
# 4                            0      9          1            1       0
# 5                            0      1          1            1       1
# ...                        ...    ...        ...          ...     ...
# 23870                        0      4          2            2       0
# 23872                        0      7          0            0       0
# 23873                        0      2          1            2       1
# 23875                        0      0          1            1       0
# 23877                        0     10          1            0       0
#
#        n_contact  n_month  n_poutcome
# 0              0        9           2
# 1              0        8           1
# 3              0        8           1
# 4              0        1           1
# 5              0        1           1
# ...          ...      ...         ...
# 23870          0        9           1
# 23872          0        0           0
# 23873          0        3           1
# 23875          0        3           2
# 23877          0        8           1
#
# [14632 rows x 14 columns]

# %%
LR,UR=Outdet(outcome_one.customer_age)
print(LR,UR)
outcome_one=outcome_one[(outcome_one['customer_age']>LR) & (outcome_one['customer_age']< UR)]
outcome_one
# Out:
# 3.0 75.0
#        customer_age  balance  day_of_month  last_contact_duration  \
# 2              57.0    495.0            18                    796
# 7              18.0    420.0            16                    920
# 16             70.0    479.0             2                    843
# 19             28.0    340.0             4                    841
# 26             54.0   1459.0             2                    751
# ...             ...      ...           ...                    ...
# 23811          41.0    701.0            20                    702
# 23823          33.0    542.0            16                    920
# 23829          47.0    127.0             3                    872
# 23842          27.0    614.0            18                    888
# 23874          51.0    298.0            15                    891
#
#        num_contacts_in_campaign  num_contacts_prev_campaign  \
# 2                           4.0                           0
# 7                           1.0                           0
# 16                          2.0                           0
# 19                          3.0                           0
# 26                          2.0                           1
# ...                         ...                         ...
# 23811                       2.0                           2
# 23823                       1.0                           4
# 23829                       2.0                           0
# 23842                       1.0                           0
# 23874                       4.0                           1
#
#        term_deposit_subscribed  n_job  n_marital  n_education  n_loan  \
# 2                            1      1          1            0       0
# 7                            1      1          2            1       0
# 16                           1      5          0            0       0
# 19                           1      7          2            0       0
# 26                           1      4          1            2       0
# ...                        ...    ...        ...          ...     ...
# 23811                        1      1          1            1       1
# 23823                        1      9          1            1       0
# 23829                        1      1          0            0       0
# 23842                        1      9          2            2       0
# 23874                        1      4          2            2       0
#
#        n_contact  n_month  n_poutcome
# 2              0        1           1
# 7              0        0           1
# 16             0        5           1
# 19             0        5           1
# 26             0       10           3
# ...          ...      ...         ...
# 23811          0        9           2
# 23823          0        0           0
# 23829          0        6           1
# 23842          0        8           1
# 23874          0        8           0
#
# [1884 rows x 14 columns]

# %%
df_1=pd.concat([outcome_zero,outcome_one],axis=0)
df_1
# Out:
#        customer_age  balance  day_of_month  last_contact_duration  \
# 0              34.0    934.0            18                    704
# 1              41.0   1352.0            13                    893
# 3              37.0    650.0            26                    880
# 4              29.0    265.0            19                    795
# 5              50.0    407.0             7                    807
# ...             ...      ...           ...                    ...
# 23811          41.0    701.0            20                    702
# 23823          33.0    542.0            16                    920
# 23829          47.0    127.0             3                    872
# 23842          27.0    614.0            18                    888
# 23874          51.0    298.0            15                    891
#
#        num_contacts_in_campaign  num_contacts_prev_campaign  \
# 0                           2.0                           1
# 1                           2.0                           0
# 3                           1.0                           0
# 4                           2.0                           0
# 5                           2.0                           0
# ...                         ...                         ...
# 23811                       2.0                           2
# 23823                       1.0                           4
# 23829                       2.0                           0
# 23842                       1.0                           0
# 23874                       4.0                           1
#
#        term_deposit_subscribed  n_job  n_marital  n_education  n_loan  \
# 0                            0      1          1            1       1
# 1                            0      1          1            0       0
# 3                            0      4          1            2       0
# 4                            0      9          1            1       0
# 5                            0      1          1            1       1
# ...                        ...    ...        ...          ...     ...
# 23811                        1      1          1            1       1
# 23823                        1      9          1            1       0
# 23829                        1      1          0            0       0
# 23842                        1      9          2            2       0
# 23874                        1      4          2            2       0
#
#        n_contact  n_month  n_poutcome
# 0              0        9           2
# 1              0        8           1
# 3              0        8           1
# 4              0        1           1
# 5              0        1           1
# ...          ...      ...         ...
# 23811          0        9           2
# 23823          0        0           0
# 23829          0        6           1
# 23842          0        8           1
# 23874          0        8           0
#
# [16516 rows x 14 columns]

# %%
df_1.term_deposit_subscribed.value_counts()
# Out:
# 0    14632
# 1     1884
# Name: term_deposit_subscribed, dtype: int64

# %%
figure, axis = plt.subplots(3, 4, figsize = (60,25))
sns.boxplot(x='term_deposit_subscribed',y='customer_age',data=df_1,ax=axis[0,0])
sns.boxplot(x='term_deposit_subscribed',y='balance',data=df_1,ax=axis[0,1])
sns.boxplot(x='term_deposit_subscribed',y='last_contact_duration',data=df_1,ax=axis[0,2])
sns.boxplot(x='term_deposit_subscribed',y='num_contacts_in_campaign',data=df_1,ax=axis[0,3])
sns.boxplot(x='term_deposit_subscribed',y='num_contacts_prev_campaign',data=df_1,ax=axis[1,0])
sns.boxplot(x='term_deposit_subscribed',y='n_job',data=df_1,ax=axis[1,1])
sns.boxplot(x='term_deposit_subscribed',y='n_marital',data=df_1,ax=axis[1,2])
sns.boxplot(x='term_deposit_subscribed',y='n_education',data=df_1,ax=axis[1,3])
sns.boxplot(x='term_deposit_subscribed',y='n_loan',data=df_1,ax=axis[2,0])
sns.boxplot(x='term_deposit_subscribed',y='n_contact',data=df_1,ax=axis[2,1])
sns.boxplot(x='term_deposit_subscribed',y='n_month',data=df_1,ax=axis[2,2])
sns.boxplot(x='term_deposit_subscribed',y='n_poutcome',data=df_1,ax=axis[2,3])
# Out:
# <AxesSubplot:xlabel='term_deposit_subscribed', ylabel='n_poutcome'>

# %%
plt.figure(figsize=(20,20))
sns.heatmap(df_1.corr(),annot =True)
# Out:
# <AxesSubplot:>

# %%
df_1
# Out:
#        customer_age  balance  day_of_month  last_contact_duration  \
# 0              34.0    934.0            18                    704
# 1              41.0   1352.0            13                    893
# 3              37.0    650.0            26                    880
# 4              29.0    265.0            19                    795
# 5              50.0    407.0             7                    807
# ...             ...      ...           ...                    ...
# 23811          41.0    701.0            20                    702
# 23823          33.0    542.0            16                    920
# 23829          47.0    127.0             3                    872
# 23842          27.0    614.0            18                    888
# 23874          51.0    298.0            15                    891
#
#        num_contacts_in_campaign  num_contacts_prev_campaign  \
# 0                           2.0                           1
# 1                           2.0                           0
# 3                           1.0                           0
# 4                           2.0                           0
# 5                           2.0                           0
# ...                         ...                         ...
# 23811                       2.0                           2
# 23823                       1.0                           4
# 23829                       2.0                           0
# 23842                       1.0                           0
# 23874                       4.0                           1
#
#        term_deposit_subscribed  n_job  n_marital  n_education  n_loan  \
# 0                            0      1          1            1       1
# 1                            0      1          1            0       0
# 3                            0      4          1            2       0
# 4                            0      9          1            1       0
# 5                            0      1          1            1       1
# ...                        ...    ...        ...          ...     ...
# 23811                        1      1          1            1       1
# 23823                        1      9          1            1       0
# 23829                        1      1          0            0       0
# 23842                        1      9          2            2       0
# 23874                        1      4          2            2       0
#
#        n_contact  n_month  n_poutcome
# 0              0        9           2
# 1              0        8           1
# 3              0        8           1
# 4              0        1           1
# 5              0        1           1
# ...          ...      ...         ...
# 23811          0        9           2
# 23823          0        0           0
# 23829          0        6           1
# 23842          0        8           1
# 23874          0        8           0
#
# [16516 rows x 14 columns]

# %% [markdown]
# ## SMOTE

# %%
x=df_1.drop(['term_deposit_subscribed','customer_age','day_of_month','n_job','n_marital','n_poutcome'],axis=1).values
print(x)
y=df_1['term_deposit_subscribed']
print(y)
# Out:
# [[9.340e+02 7.040e+02 2.000e+00 ... 1.000e+00 0.000e+00 9.000e+00]
#  [1.352e+03 8.930e+02 2.000e+00 ... 0.000e+00 0.000e+00 8.000e+00]
#  [6.500e+02 8.800e+02 1.000e+00 ... 0.000e+00 0.000e+00 8.000e+00]
#  ...
#  [1.270e+02 8.720e+02 2.000e+00 ... 0.000e+00 0.000e+00 6.000e+00]
#  [6.140e+02 8.880e+02 1.000e+00 ... 0.000e+00 0.000e+00 8.000e+00]
#  [2.980e+02 8.910e+02 4.000e+00 ... 0.000e+00 0.000e+00 8.000e+00]]
# 0        0
# 1        0
# 3        0
# 4        0
# 5        0
#         ..
# 23811    1
# 23823    1
# 23829    1
# 23842    1
# 23874    1
# Name: term_deposit_subscribed, Length: 16516, dtype: int64

# %%
pip install imbalanced-learn
# Out:
# Requirement already satisfied: imbalanced-learn in c:\users\mini9\anaconda\lib\site-packages (0.9.0)
# Requirement already satisfied: scikit-learn>=1.0.1 in c:\users\mini9\anaconda\lib\site-packages (from imbalanced-learn) (1.0.2)
# Requirement already satisfied: threadpoolctl>=2.0.0 in c:\users\mini9\anaconda\lib\site-packages (from imbalanced-learn) (2.1.0)
# Requirement already satisfied: numpy>=1.14.6 in c:\users\mini9\anaconda\lib\site-packages (from imbalanced-learn) (1.19.2)
# Requirement already satisfied: joblib>=0.11 in c:\users\mini9\anaconda\lib\site-packages (from imbalanced-learn) (0.17.0)
# Requirement already satisfied: scipy>=1.1.0 in c:\users\mini9\anaconda\lib\site-packages (from imbalanced-learn) (1.5.2)
# Note: you may need to restart the kernel to use updated packages.
# WARNING: You are using pip version 21.2.4; however, version 22.0.4 is available.
# You should consider upgrading via the 'C:\Users\mini9\Anaconda\python.exe -m pip install --upgrade pip' command.

# %%
from imblearn.over_sampling import SMOTE

smote = SMOTE(sampling_strategy='minority')
X_sm, y_sm = smote.fit_resample(x, y)

y_sm.value_counts()
# Out:
# 1    14632
# 0    14632
# Name: term_deposit_subscribed, dtype: int64

# %%
from sklearn.model_selection import train_test_split
x_train, x_test, y_train, y_test = train_test_split(X_sm, y_sm, test_size=0.2, random_state=15, stratify=y_sm)

# %% [markdown]
# ## Scaling of data

# %%
from sklearn.preprocessing import StandardScaler
std_model=StandardScaler()
x_train_std_features=std_model.fit_transform(x_train)
x_test_std_features=std_model.transform(x_test)

# %%
x_train_std_features.shape
# Out:
# (23411, 8)

# %%
x_test_std_features.shape
# Out:
# (5853, 8)

# %% [markdown]
# ## Logistic Regression

# %%
from sklearn.linear_model import LogisticRegression
modelreg=LogisticRegression()
modelreg.fit(x_train_std_features,y_train)
# Out:
# LogisticRegression()

# %%
ypred=modelreg.predict(x_test_std_features)
ypred
# Out:
# array([0, 0, 1, ..., 1, 1, 1], dtype=int64)

# %%
modelreg.score(x_test_std_features,y_test)
# Out:
# 0.6541944302067316

# %%
x_test_std_features.shape
# Out:
# (5853, 8)

# %%
y_test.shape
# Out:
# (5853,)

# %%
from sklearn import metrics
print("Accuracy:",metrics.accuracy_score(y_test, ypred))
print("Precision:",metrics.precision_score(y_test, ypred))
print("Recall:",metrics.recall_score(y_test, ypred))
# Out:
# Accuracy: 0.6541944302067316
# Precision: 0.668158090976883
# Recall: 0.6124401913875598

# %%
cnf_matrix = metrics.confusion_matrix(y_test, ypred)
cnf_matrix
# Out:
# array([[2037,  890],
#        [1134, 1792]], dtype=int64)

# %% [markdown]
# ## KNN

# %%
from sklearn.neighbors import KNeighborsClassifier
KNN_model = KNeighborsClassifier(n_neighbors = 5, metric = 'minkowski', p = 2)
KNN_model.fit(x_train_std_features, y_train)
# Out:
# KNeighborsClassifier()

# %%
y_predicted_KNN = KNN_model.predict(x_test_std_features)

# %%
KNN_model.score(x_test_std_features,y_test)
# Out:
# 0.8718605843157355

# %%
print("Accuracy:",metrics.accuracy_score(y_test, y_predicted_KNN))
print("Precision:",metrics.precision_score(y_test,y_predicted_KNN))
print("Recall:",metrics.recall_score(y_test, y_predicted_KNN))
# Out:
# Accuracy: 0.8718605843157355
# Precision: 0.8976608187134503
# Recall: 0.8393711551606289

# %%
## Naive Byes

from sklearn.naive_bayes import GaussianNB
naive_bayes_model= GaussianNB()
naive_bayes_model.fit(x_train_std_features, y_train)
# Out:
# GaussianNB()

# %%
y_predicted_naive = naive_bayes_model.predict(x_test_std_features)

# %%
naive_bayes_model.score(x_test_std_features,y_test)
# Out:
# 0.6570989236289082

# %%
print("Accuracy:",metrics.accuracy_score(y_test, y_predicted_naive))
print("Precision:",metrics.precision_score(y_test,y_predicted_naive))
print("Recall:",metrics.recall_score(y_test, y_predicted_naive))
# Out:
# Accuracy: 0.6570989236289082
# Precision: 0.6492367651835012
# Recall: 0.6831852358168148

# %%
from sklearn.tree import DecisionTreeClassifier
deseciontree_model=DecisionTreeClassifier()
deseciontree_model.fit(x_train_std_features, y_train)

y_predicted_deseciontree = deseciontree_model.predict(x_test_std_features)
deseciontree_model.score(x_test_std_features,y_test)
# Out:
# 0.9120109345634717

# %%
print("Accuracy:",metrics.accuracy_score(y_test,y_predicted_deseciontree))
print("Precision:",metrics.precision_score(y_test,y_predicted_deseciontree))
print("Recall:",metrics.recall_score(y_test, y_predicted_deseciontree))
# Out:
# Accuracy: 0.9120109345634717
# Precision: 0.9104528430371127
# Recall: 0.9138755980861244

# %%
from sklearn.ensemble import RandomForestClassifier
randomforest_model= RandomForestClassifier(n_estimators = 10, criterion = 'entropy')
randomforest_model.fit(x_train_std_features, y_train)

y_predicted_randomforest = randomforest_model.predict(x_test_std_features)
randomforest_model.score(x_test_std_features,y_test)
# Out:
# 0.9361011447121135

# %%
print("Accuracy:",metrics.accuracy_score(y_test,y_predicted_randomforest))
print("Precision:",metrics.precision_score(y_test,y_predicted_randomforest))
print("Recall:",metrics.recall_score(y_test, y_predicted_randomforest))
# Out:
# Accuracy: 0.9361011447121135
# Precision: 0.9583333333333334
# Recall: 0.911825017088175

# %%
from sklearn.svm import SVC
SVM_model_rbf=SVC(kernel='rbf')
SVM_model_rbf.fit(x_train_std_features,y_train)

y_predicted_SVM_rbf = SVM_model_rbf.predict(x_test_std_features)
SVM_model_rbf.score(x_test_std_features,y_test)
# Out:
# 0.8002733640867931

# %%
print("Accuracy:",metrics.accuracy_score(y_test,y_predicted_SVM_rbf))
print("Precision:",metrics.precision_score(y_test,y_predicted_SVM_rbf))
print("Recall:",metrics.recall_score(y_test, y_predicted_SVM_rbf))
# Out:
# Accuracy: 0.8002733640867931
# Precision: 0.863768115942029
# Recall: 0.7129186602870813

# %%
from sklearn.svm import SVC
SVM_model_linear=SVC(kernel='linear')
SVM_model_linear.fit(x_train_std_features,y_train)

y_predicted_SVM_linear = SVM_model_linear.predict(x_test_std_features)
SVM_model_linear.score(x_test_std_features,y_test)
# Out:
# 0.6591491542798564

# %%
print("Accuracy:",metrics.accuracy_score(y_test,y_predicted_SVM_linear))
print("Precision:",metrics.precision_score(y_test,y_predicted_SVM_linear))
print("Recall:",metrics.recall_score(y_test, y_predicted_SVM_linear))
# Out:
# Accuracy: 0.6591491542798564
# Precision: 0.7051564565888057
# Recall: 0.5468215994531784

# %%
from sklearn.ensemble import GradientBoostingClassifier
GradientB_model=GradientBoostingClassifier(n_estimators=100,learning_rate=1.0)

GradientB_model.fit(x_train_std_features,y_train)
y_predicted_GradientB = GradientB_model.predict(x_test_std_features)
GradientB_model.score(x_test_std_features,y_test)
# Out:
# 0.9378096702545703

# %%
print("Accuracy:",metrics.accuracy_score(y_test,y_predicted_GradientB))
print("Precision:",metrics.precision_score(y_test,y_predicted_GradientB))
print("Recall:",metrics.recall_score(y_test, y_predicted_GradientB))
# Out:
# Accuracy: 0.9378096702545703
# Precision: 0.9692307692307692
# Recall: 0.9043062200956937

# %%
from sklearn.ensemble import AdaBoostClassifier
Adaboost_model=AdaBoostClassifier(n_estimators=100)
Adaboost_model.fit(x_train_std_features,y_train)
y_predicted_Adaboost = Adaboost_model.predict(x_test_std_features)
Adaboost_model.score(x_test_std_features,y_test)
# Out:
# 0.9191867418417905

# %%
print("Accuracy:",metrics.accuracy_score(y_test,y_predicted_Adaboost))
print("Precision:",metrics.precision_score(y_test,y_predicted_Adaboost))
print("Recall:",metrics.recall_score(y_test, y_predicted_Adaboost))
# Out:
# Accuracy: 0.9191867418417905
# Precision: 0.9733693554612118
# Recall: 0.8619275461380724

# %%
from sklearn.metrics import classification_report,roc_auc_score,roc_curve,auc
report_Adaboost = classification_report(y_test,y_predicted_Adaboost)
print(report_Adaboost)
# Out:
#               precision    recall  f1-score   support
#
#            0       0.88      0.98      0.92      2927
#            1       0.97      0.86      0.91      2926
#
#     accuracy                           0.92      5853
#    macro avg       0.92      0.92      0.92      5853
# weighted avg       0.92      0.92      0.92      5853
